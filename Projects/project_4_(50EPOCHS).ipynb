# %% [markdown]
# ## Generative Adversarial Network (GAN) with Python and Tensorflow

# %% [markdown]
# ### Import dependencies

# %%
# dataset and visualization components
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
import numpy as np

# modeling components
from keras.models import Sequential
from keras.layers import Conv2D, Dense, Flatten, Reshape, LeakyReLU, Dropout, UpSampling2D

# losses and optimizers components
from keras.optimizers import Adam
from keras.losses import BinaryCrossentropy

# subclassed model components
import tensorflow as tf
from keras.models import Model

# callback components
import os
from keras.utils import array_to_img
from keras.callbacks import Callback

# %% [markdown]
# ### Load and visualize data

# %%
# Load the mnist dataset from tensorflow_datasets
ds = tfds.load('mnist', split='train')
# Out:
# Downloading and preparing dataset 11.06 MiB (download: 11.06 MiB, generated: 21.00 MiB, total: 32.06 MiB) to /root/tensorflow_datasets/mnist/3.0.1...
# Dl Completed...:   0%|          | 0/5 [00:00<?, ? file/s]
# Dataset mnist downloaded and prepared to /root/tensorflow_datasets/mnist/3.0.1. Subsequent calls will reuse this data.

# %%
# Convert the data to a numpy iterator
data_iterator = ds.as_numpy_iterator()

# Visualize the data
fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx in range(4): 
    # Grab an image and label
    sample = data_iterator.next()
    ax[idx].imshow(np.squeeze(sample['image']))
    ax[idx].title.set_text(sample['label'])

# %% [markdown]
# ### Pre-process data

# %%
# Scale all the images
def scale_images(data): 
    image = data['image']
    return image / 255

# %%
# Running the dataset through the scale_images preprocessing step
ds = ds.map(scale_images) 
# Cache the dataset for that batch 
ds = ds.cache()
# Shuffle it up 
ds = ds.shuffle(60000)
# Batch into 128 images per sample
ds = ds.batch(128)
# Reduces the likelihood of bottlenecking 
ds = ds.prefetch(64)

# %%
ds.as_numpy_iterator().next().shape
# Out:
# (128, 28, 28, 1)

# %% [markdown]
# ### Build the generator

# %%
def build_generator():
    model = Sequential()                       # define our model
    model.add(Dense(7*7*128, input_dim=128))   # add Dense layer with random noise as input
    model.add(LeakyReLU(0.2))                  # apply LeakyRelu activation
    model.add(Reshape((7,7,128)))              # reshape to 17*17*128

    # Upsampling block - 1
    model.add(UpSampling2D())                  # layer used to increase the spatial resolution of the input
    model.add(Conv2D(128, 5, padding='same'))  # convolutional nn layer with 128 units, kernel size 5x5 and padding same
    model.add(LeakyReLU(0.2))                  # apply LeakyRelu activation

    # Upsampling block - 2
    model.add(UpSampling2D())                  # layer used to increase the spatial resolution of the input
    model.add(Conv2D(128, 5, padding='same'))  # convolutional nn layer with 128 units, kernel size 5x5 and padding same
    model.add(LeakyReLU(0.2))                  # apply LeakyRelu activation

    # Downsampling block - 1
    model.add(Conv2D(128, 4, padding='same'))  # convolutional nn layer with 128 units, kernel size 4x4 and padding same
    model.add(LeakyReLU(0.2))                  # apply LeakyRelu activation

    # Downsampling block - 2
    model.add(Conv2D(128, 4, padding='same'))  # convolutional nn layer with 128 units, kernel size 4x4 and padding same
    model.add(LeakyReLU(0.2))                  # apply LeakyRelu activation

    # convolutional nn layer to change to 1 channel,kernel size 4x4, same padding and a sigmoid activation this time
    model.add(Conv2D(1, 4, padding='same', activation='sigmoid'))

    # return the model
    return model

# %%
# generator summary
generator = build_generator()
generator.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 6272)              809088
#
#  leaky_re_lu (LeakyReLU)     (None, 6272)              0
#
#  reshape (Reshape)           (None, 7, 7, 128)         0
#
#  up_sampling2d (UpSampling2D  (None, 14, 14, 128)      0
#  )
#
#  conv2d (Conv2D)             (None, 14, 14, 128)       409728
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 14, 14, 128)       0
#
#  up_sampling2d_1 (UpSampling  (None, 28, 28, 128)      0
#  2D)
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 128)       409728
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 28, 28, 128)       0
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 128)       262272
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 28, 28, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 128)       262272
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 28, 28, 128)       0
#
#  conv2d_4 (Conv2D)           (None, 28, 28, 1)         2049
#
# =================================================================
# Total params: 2,155,137
# Trainable params: 2,155,137
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Test the generator

# %%
# Generate 4 new images
img = generator.predict(np.random.randn(4,128,1))

# Setup the subplot formatting 
fig, ax = plt.subplots(ncols=4, figsize=(20,20))
# Loop 4 times and get images 
for idx, img in enumerate(img): 
    # Plot the image using a specific subplot 
    ax[idx].imshow(np.squeeze(img))
    ax[idx].title.set_text(idx)
# Out:
# 1/1 [==============================] - 8s 8s/step

# %% [markdown]
# ### Build the discriminator

# %%
def build_discriminator(): 
    model = Sequential()
    
    # First Conv Block
    model.add(Conv2D(32, 5, input_shape = (28,28,1)))
    model.add(LeakyReLU(0.2))
    model.add(Dropout(0.4))
    
    # Second Conv Block
    model.add(Conv2D(64, 5))
    model.add(LeakyReLU(0.2))
    model.add(Dropout(0.4))
    
    # Third Conv Block
    model.add(Conv2D(128, 5))
    model.add(LeakyReLU(0.2))
    model.add(Dropout(0.4))
    
    # Fourth Conv Block
    model.add(Conv2D(256, 5))
    model.add(LeakyReLU(0.2))
    model.add(Dropout(0.4))
    
    # Flatten then pass to dense layer
    model.add(Flatten())
    model.add(Dropout(0.4))
    model.add(Dense(1, activation='sigmoid'))
    
    return model

# %%
# discriminator summary
discriminator = build_discriminator()
discriminator.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 24, 24, 32)        832
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 24, 24, 32)        0
#
#  dropout (Dropout)           (None, 24, 24, 32)        0
#
#  conv2d_6 (Conv2D)           (None, 20, 20, 64)        51264
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 20, 20, 64)        0
#
#  dropout_1 (Dropout)         (None, 20, 20, 64)        0
#
#  conv2d_7 (Conv2D)           (None, 16, 16, 128)       204928
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 16, 16, 128)       0
#
#  dropout_2 (Dropout)         (None, 16, 16, 128)       0
#
#  conv2d_8 (Conv2D)           (None, 12, 12, 256)       819456
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 12, 12, 256)       0
#
#  dropout_3 (Dropout)         (None, 12, 12, 256)       0
#
#  flatten (Flatten)           (None, 36864)             0
#
#  dropout_4 (Dropout)         (None, 36864)             0
#
#  dense_1 (Dense)             (None, 1)                 36865
#
# =================================================================
# Total params: 1,113,345
# Trainable params: 1,113,345
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Test the discriminator

# %%
# generate 4 images
img = generator.predict(np.random.randn(4,128,1))
# use the discriminator to predict the images made by the generator
discriminator.predict(img)
# Out:
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 255ms/step
# array([[0.49539998],
#        [0.4954324 ],
#        [0.49522147],
#        [0.495512  ]], dtype=float32)

# %% [markdown]
# ### Build training loop

# %%
# setup losses and optimizers
g_opt = Adam(learning_rate=0.0001) 
d_opt = Adam(learning_rate=0.00001) 
g_loss = BinaryCrossentropy()
d_loss = BinaryCrossentropy()

# %%
# build subclassed model
class numbersGAN(Model): 
    def __init__(self, generator, discriminator, *args, **kwargs):
        # Pass through args and kwargs to base class 
        super().__init__(*args, **kwargs)
        
        # Create attributes for gen and disc
        self.generator = generator 
        self.discriminator = discriminator 
        
    def compile(self, g_opt, d_opt, g_loss, d_loss, *args, **kwargs): 
        # Compile with base class
        super().compile(*args, **kwargs)
        
        # Create attributes for losses and optimizers
        self.g_opt = g_opt
        self.d_opt = d_opt
        self.g_loss = g_loss
        self.d_loss = d_loss 

    def train_step(self, batch):
        # Get the data 
        real_images = batch
        fake_images = self.generator(tf.random.normal((128, 128, 1)), training=False)
        
        # Train the discriminator
        with tf.GradientTape() as d_tape: 
            # Pass the real and fake images to the discriminator model
            yhat_real = self.discriminator(real_images, training=True) 
            yhat_fake = self.discriminator(fake_images, training=True)
            yhat_realfake = tf.concat([yhat_real, yhat_fake], axis=0)
            
            # Create labels for real and fakes images
            y_realfake = tf.concat([tf.zeros_like(yhat_real), tf.ones_like(yhat_fake)], axis=0)
            
            # Add some noise to the TRUE outputs
            noise_real = 0.15*tf.random.uniform(tf.shape(yhat_real))
            noise_fake = -0.15*tf.random.uniform(tf.shape(yhat_fake))
            y_realfake += tf.concat([noise_real, noise_fake], axis=0)
            
            # Calculate loss - BINARYCROSS 
            total_d_loss = self.d_loss(y_realfake, yhat_realfake)
            
        # Apply backpropagation - nn learn 
        dgrad = d_tape.gradient(total_d_loss, self.discriminator.trainable_variables) 
        self.d_opt.apply_gradients(zip(dgrad, self.discriminator.trainable_variables))
        
        # Train the generator
        with tf.GradientTape() as g_tape: 
            # Generate some new images
            gen_images = self.generator(tf.random.normal((128,128,1)), training=True)
                                        
            # Create the predicted labels
            predicted_labels = self.discriminator(gen_images, training=False)
                                        
            # Calculate loss - trick to training to fake out the discriminator
            total_g_loss = self.g_loss(tf.zeros_like(predicted_labels), predicted_labels) 
            
        # Apply backprop
        ggrad = g_tape.gradient(total_g_loss, self.generator.trainable_variables)
        self.g_opt.apply_gradients(zip(ggrad, self.generator.trainable_variables))
        
        return {"d_loss":total_d_loss, "g_loss":total_g_loss}

# %%
# Create instance of subclassed model
numgan = numbersGAN(generator, discriminator)
# Compile the model
numgan.compile(g_opt, d_opt, g_loss, d_loss)

# %% [markdown]
# ### Build callback

# %%
class ModelMonitor(Callback):
    def __init__(self, num_img=3, latent_dim=128):
        self.num_img = num_img
        self.latent_dim = latent_dim

    def on_epoch_end(self, epoch, logs=None):
        random_latent_vectors = tf.random.uniform((self.num_img, self.latent_dim,1))
        generated_images = self.model.generator(random_latent_vectors)
        generated_images *= 255
        generated_images.numpy()
        for i in range(self.num_img):
            img = array_to_img(generated_images[i])
            img.save(os.path.join('images', f'generated_img_{epoch}_{i}.png'))

# %% [markdown]
# ### Train the model

# %%
# Recommend 1500-2000 epochs
hist = numgan.fit(ds, epochs=50, callbacks=[ModelMonitor()])
# Out:
# Epoch 1/50
#   6/469 [..............................] - ETA: 1:15 - d_loss: 0.6939 - g_loss: 0.6912
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0679s vs `on_train_batch_end` time: 0.0783s). Check your callbacks.
# 469/469 [==============================] - 87s 171ms/step - d_loss: 0.4424 - g_loss: 1.3021
# Epoch 2/50
# 469/469 [==============================] - 82s 175ms/step - d_loss: 0.2691 - g_loss: 2.5653
# Epoch 3/50
# 469/469 [==============================] - 82s 174ms/step - d_loss: 0.2684 - g_loss: 2.5991
# Epoch 4/50
# 469/469 [==============================] - 82s 174ms/step - d_loss: 0.2683 - g_loss: 2.6013
# Epoch 5/50
# 469/469 [==============================] - 82s 174ms/step - d_loss: 0.2937 - g_loss: 2.5122
# Epoch 6/50
# 469/469 [==============================] - 82s 175ms/step - d_loss: 0.6628 - g_loss: 0.8071
# Epoch 7/50
# 469/469 [==============================] - 82s 175ms/step - d_loss: 0.7002 - g_loss: 0.6421
# Epoch 8/50
# 469/469 [==============================] - 82s 175ms/step - d_loss: 0.6918 - g_loss: 0.7022
# Epoch 9/50
# 469/469 [==============================] - 82s 176ms/step - d_loss: 0.6933 - g_loss: 0.7132
# Epoch 10/50
# 469/469 [==============================] - 82s 175ms/step - d_loss: 0.6935 - g_loss: 0.7354
# Epoch 11/50
# 469/469 [==============================] - 82s 175ms/step - d_loss: 0.6956 - g_loss: 0.7279
# Epoch 12/50
# 469/469 [==============================] - 82s 176ms/step - d_loss: 0.6939 - g_loss: 0.7327
# Epoch 13/50
# 469/469 [==============================] - 82s 175ms/step - d_loss: 0.6950 - g_loss: 0.7189
# Epoch 14/50
# 469/469 [==============================] - 83s 176ms/step - d_loss: 0.6945 - g_loss: 0.7142
# Epoch 15/50
# 469/469 [==============================] - 82s 175ms/step - d_loss: 0.6935 - g_loss: 0.7050
# Epoch 16/50
# 469/469 [==============================] - 82s 176ms/step - d_loss: 0.6929 - g_loss: 0.7028
# Epoch 17/50
# 469/469 [==============================] - 82s 175ms/step - d_loss: 0.6926 - g_loss: 0.6963
# Epoch 18/50
# 469/469 [==============================] - 82s 176ms/step - d_loss: 0.6944 - g_loss: 0.6922
# Epoch 19/50
# 469/469 [==============================] - 82s 175ms/step - d_loss: 0.6936 - g_loss: 0.6953
# Epoch 20/50
# 469/469 [==============================] - 82s 175ms/step - d_loss: 0.6936 - g_loss: 0.6963
# Epoch 21/50
# 469/469 [==============================] - 82s 175ms/step - d_loss: 0.6964 - g_loss: 0.6842
# Epoch 22/50
# 469/469 [==============================] - 82s 175ms/step - d_loss: 0.6934 - g_loss: 0.6855
# Epoch 23/50
# 469/469 [==============================] - 82s 175ms/step - d_loss: 0.6965 - g_loss: 0.6876
# Epoch 24/50
# 469/469 [==============================] - 82s 175ms/step - d_loss: 0.6943 - g_loss: 0.6882
# Epoch 25/50
# 469/469 [==============================] - 82s 176ms/step - d_loss: 0.6949 - g_loss: 0.6873
# Epoch 26/50
# 469/469 [==============================] - 82s 175ms/step - d_loss: 0.6957 - g_loss: 0.6830
# Epoch 27/50
# 469/469 [==============================] - 82s 175ms/step - d_loss: 0.6935 - g_loss: 0.6834
# Epoch 28/50
# 469/469 [==============================] - 82s 175ms/step - d_loss: 0.6936 - g_loss: 0.6862
# Epoch 29/50
# 469/469 [==============================] - 82s 175ms/step - d_loss: 0.6918 - g_loss: 0.6946
# Epoch 30/50
# 469/469 [==============================] - 82s 175ms/step - d_loss: 0.6989 - g_loss: 0.6690
# Epoch 31/50
# 469/469 [==============================] - 82s 175ms/step - d_loss: 0.6926 - g_loss: 0.6800
# Epoch 32/50
# 469/469 [==============================] - 82s 175ms/step - d_loss: 0.6972 - g_loss: 0.6828
# Epoch 33/50
# 469/469 [==============================] - 82s 175ms/step - d_loss: 0.6927 - g_loss: 0.6884
# Epoch 34/50
# 469/469 [==============================] - 82s 175ms/step - d_loss: 0.6951 - g_loss: 0.6924
# Epoch 35/50
# 469/469 [==============================] - 82s 175ms/step - d_loss: 0.6956 - g_loss: 0.6823
# Epoch 36/50
# 469/469 [==============================] - 82s 175ms/step - d_loss: 0.6948 - g_loss: 0.6922
# Epoch 37/50
# 469/469 [==============================] - 82s 176ms/step - d_loss: 0.6926 - g_loss: 0.6851
# Epoch 38/50
# 469/469 [==============================] - 82s 175ms/step - d_loss: 0.6956 - g_loss: 0.6888
# Epoch 39/50
# 469/469 [==============================] - 82s 175ms/step - d_loss: 0.6924 - g_loss: 0.6846
# Epoch 40/50
# 469/469 [==============================] - 82s 175ms/step - d_loss: 0.6957 - g_loss: 0.6884
# Epoch 41/50
# 469/469 [==============================] - 82s 175ms/step - d_loss: 0.6945 - g_loss: 0.6872
# Epoch 42/50
# 469/469 [==============================] - 82s 175ms/step - d_loss: 0.6928 - g_loss: 0.6806
# Epoch 43/50
# 469/469 [==============================] - 82s 175ms/step - d_loss: 0.6960 - g_loss: 0.6908
# Epoch 44/50
# 469/469 [==============================] - 82s 175ms/step - d_loss: 0.6934 - g_loss: 0.6861
# Epoch 45/50
# 469/469 [==============================] - 82s 175ms/step - d_loss: 0.6943 - g_loss: 0.6886
# Epoch 46/50
# 469/469 [==============================] - 82s 175ms/step - d_loss: 0.6951 - g_loss: 0.6944
# Epoch 47/50
# 469/469 [==============================] - 82s 175ms/step - d_loss: 0.6873 - g_loss: 0.6895
# Epoch 48/50
# 469/469 [==============================] - 82s 175ms/step - d_loss: 0.6994 - g_loss: 0.6808
# Epoch 49/50
# 469/469 [==============================] - 82s 175ms/step - d_loss: 0.6936 - g_loss: 0.6929
# Epoch 50/50
# 469/469 [==============================] - 82s 175ms/step - d_loss: 0.6953 - g_loss: 0.6859

# %% [markdown]
# ### Revew model performance

# %%
plt.suptitle('Loss')
plt.plot(hist.history['d_loss'], label='d_loss')
plt.plot(hist.history['g_loss'], label='g_loss')
plt.legend()
plt.show()

# %% [markdown]
# ### Test the trained generator

# %%
# generate new images
imgs = generator.predict(tf.random.normal((16, 128, 1)))
# plot the generated images
fig, ax = plt.subplots(ncols=4, nrows=4, figsize=(10,10))
for r in range(4): 
    for c in range(4): 
        ax[r][c].imshow(imgs[(r+1)*(c+1)-1])
# Out:
# 1/1 [==============================] - 0s 310ms/step

# %% [markdown]
# ### Save the model

# %%
generator.save('generator.h5')
discriminator.save('discriminator.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# !zip -r /content/images.zip /content/images
# Out:
#   adding: content/images/ (stored 0%)
#   adding: content/images/generated_img_15_1.png (stored 0%)
#   adding: content/images/generated_img_4_1.png (stored 0%)
#   adding: content/images/generated_img_48_1.png (stored 0%)
#   adding: content/images/generated_img_30_0.png (stored 0%)
#   adding: content/images/generated_img_40_2.png (stored 0%)
#   adding: content/images/generated_img_22_1.png (stored 0%)
#   adding: content/images/generated_img_47_0.png (stored 0%)
#   adding: content/images/generated_img_29_0.png (stored 0%)
#   adding: content/images/generated_img_1_2.png (deflated 5%)
#   adding: content/images/generated_img_9_0.png (stored 0%)
#   adding: content/images/generated_img_19_0.png (stored 0%)
#   adding: content/images/generated_img_13_2.png (stored 0%)
#   adding: content/images/generated_img_46_2.png (stored 0%)
#   adding: content/images/generated_img_45_2.png (stored 0%)
#   adding: content/images/generated_img_43_0.png (stored 0%)
#   adding: content/images/generated_img_21_2.png (stored 0%)
#   adding: content/images/generated_img_36_0.png (stored 0%)
#   adding: content/images/generated_img_46_1.png (stored 0%)
#   adding: content/images/generated_img_38_2.png (stored 0%)
#   adding: content/images/generated_img_24_2.png (stored 0%)
#   adding: content/images/generated_img_35_1.png (stored 0%)
#   adding: content/images/generated_img_25_0.png (stored 0%)
#   adding: content/images/generated_img_33_0.png (stored 0%)
#   adding: content/images/generated_img_49_2.png (stored 0%)
#   adding: content/images/generated_img_37_0.png (stored 0%)
#   adding: content/images/generated_img_43_2.png (stored 0%)
#   adding: content/images/generated_img_20_0.png (stored 0%)
#   adding: content/images/generated_img_2_0.png (deflated 4%)
#   adding: content/images/generated_img_12_0.png (stored 0%)
#   adding: content/images/generated_img_14_0.png (stored 0%)
#   adding: content/images/generated_img_10_0.png (stored 0%)
#   adding: content/images/generated_img_29_1.png (stored 0%)
#   adding: content/images/generated_img_37_1.png (stored 0%)
#   adding: content/images/generated_img_18_0.png (stored 0%)
#   adding: content/images/generated_img_15_2.png (stored 0%)
#   adding: content/images/generated_img_13_1.png (stored 0%)
#   adding: content/images/generated_img_11_1.png (stored 0%)
#   adding: content/images/generated_img_38_0.png (stored 0%)
#   adding: content/images/generated_img_11_2.png (stored 0%)
#   adding: content/images/generated_img_15_0.png (stored 0%)
#   adding: content/images/generated_img_32_2.png (stored 0%)
#   adding: content/images/generated_img_44_0.png (stored 0%)
#   adding: content/images/generated_img_17_1.png (stored 0%)
#   adding: content/images/generated_img_6_0.png (stored 0%)
#   adding: content/images/generated_img_3_0.png (deflated 5%)
#   adding: content/images/generated_img_25_1.png (stored 0%)
#   adding: content/images/generated_img_39_2.png (stored 0%)
#   adding: content/images/generated_img_32_1.png (stored 0%)
#   adding: content/images/generated_img_41_0.png (stored 0%)
#   adding: content/images/generated_img_4_0.png (stored 0%)
#   adding: content/images/generated_img_34_1.png (stored 0%)
#   adding: content/images/generated_img_36_2.png (stored 0%)
#   adding: content/images/generated_img_1_0.png (deflated 6%)
#   adding: content/images/generated_img_46_0.png (stored 0%)
#   adding: content/images/generated_img_19_2.png (stored 0%)
#   adding: content/images/generated_img_23_0.png (stored 0%)
#   adding: content/images/generated_img_16_2.png (stored 0%)
#   adding: content/images/generated_img_21_0.png (stored 0%)
#   adding: content/images/generated_img_42_1.png (stored 0%)
#   adding: content/images/generated_img_0_1.png (deflated 4%)
#   adding: content/images/generated_img_37_2.png (stored 0%)
#   adding: content/images/generated_img_25_2.png (stored 0%)
#   adding: content/images/generated_img_8_1.png (stored 0%)
#   adding: content/images/generated_img_35_2.png (stored 0%)
#   adding: content/images/generated_img_45_1.png (stored 0%)
#   adding: content/images/generated_img_14_2.png (stored 0%)
#   adding: content/images/generated_img_40_0.png (stored 0%)
#   adding: content/images/generated_img_38_1.png (stored 0%)
#   adding: content/images/generated_img_9_1.png (stored 0%)
#   adding: content/images/generated_img_2_2.png (deflated 5%)
#   adding: content/images/generated_img_3_1.png (deflated 5%)
#   adding: content/images/generated_img_12_2.png (stored 0%)
#   adding: content/images/generated_img_18_2.png (stored 0%)
#   adding: content/images/generated_img_23_1.png (stored 0%)
#   adding: content/images/generated_img_1_1.png (deflated 4%)
#   adding: content/images/generated_img_47_1.png (stored 0%)
#   adding: content/images/generated_img_39_0.png (stored 0%)
#   adding: content/images/generated_img_26_2.png (stored 0%)
#   adding: content/images/generated_img_18_1.png (stored 0%)
#   adding: content/images/generated_img_0_0.png (deflated 4%)
#   adding: content/images/generated_img_3_2.png (deflated 6%)
#   adding: content/images/generated_img_17_0.png (stored 0%)
#   adding: content/images/generated_img_7_0.png (stored 0%)
#   adding: content/images/generated_img_49_0.png (stored 0%)
#   adding: content/images/generated_img_29_2.png (stored 0%)
#   adding: content/images/generated_img_19_1.png (stored 0%)
#   adding: content/images/generated_img_43_1.png (stored 0%)
#   adding: content/images/generated_img_34_0.png (stored 0%)
#   adding: content/images/generated_img_30_2.png (stored 0%)
#   adding: content/images/generated_img_47_2.png (stored 0%)
#   adding: content/images/generated_img_39_1.png (stored 0%)
#   adding: content/images/generated_img_9_2.png (stored 0%)
#   adding: content/images/generated_img_30_1.png (stored 0%)
#   adding: content/images/generated_img_6_1.png (stored 0%)
#   adding: content/images/generated_img_45_0.png (stored 0%)
#   adding: content/images/generated_img_7_1.png (stored 0%)
#   adding: content/images/generated_img_10_1.png (stored 0%)
#   adding: content/images/generated_img_12_1.png (stored 0%)
#   adding: content/images/generated_img_10_2.png (stored 0%)
#   adding: content/images/generated_img_48_2.png (stored 0%)
#   adding: content/images/generated_img_0_2.png (deflated 5%)
#   adding: content/images/generated_img_33_2.png (stored 0%)
#   adding: content/images/generated_img_20_1.png (stored 0%)
#   adding: content/images/generated_img_32_0.png (stored 0%)
#   adding: content/images/generated_img_7_2.png (stored 0%)
#   adding: content/images/generated_img_27_0.png (stored 0%)
#   adding: content/images/generated_img_8_2.png (stored 0%)
#   adding: content/images/generated_img_16_1.png (stored 0%)
#   adding: content/images/generated_img_44_2.png (stored 0%)
#   adding: content/images/generated_img_5_0.png (stored 0%)
#   adding: content/images/generated_img_16_0.png (stored 0%)
#   adding: content/images/generated_img_26_1.png (stored 0%)
#   adding: content/images/generated_img_49_1.png (stored 0%)
#   adding: content/images/generated_img_5_2.png (stored 0%)
#   adding: content/images/generated_img_34_2.png (stored 0%)
#   adding: content/images/generated_img_21_1.png (stored 0%)
#   adding: content/images/generated_img_14_1.png (stored 0%)
#   adding: content/images/generated_img_41_1.png (stored 0%)
#   adding: content/images/generated_img_28_2.png (stored 0%)
#   adding: content/images/generated_img_42_0.png (stored 0%)
#   adding: content/images/generated_img_22_0.png (stored 0%)
#   adding: content/images/generated_img_27_2.png (stored 0%)
#   adding: content/images/generated_img_42_2.png (stored 0%)
#   adding: content/images/generated_img_41_2.png (stored 0%)
#   adding: content/images/generated_img_11_0.png (stored 0%)
#   adding: content/images/generated_img_48_0.png (stored 0%)
#   adding: content/images/generated_img_24_0.png (stored 0%)
#   adding: content/images/generated_img_24_1.png (stored 0%)
#   adding: content/images/generated_img_26_0.png (stored 0%)
#   adding: content/images/generated_img_6_2.png (stored 0%)
#   adding: content/images/generated_img_35_0.png (stored 0%)
#   adding: content/images/generated_img_28_1.png (stored 0%)
#   adding: content/images/generated_img_22_2.png (stored 0%)
#   adding: content/images/generated_img_4_2.png (stored 0%)
#   adding: content/images/generated_img_2_1.png (deflated 5%)
#   adding: content/images/generated_img_36_1.png (stored 0%)
#   adding: content/images/generated_img_13_0.png (stored 0%)
#   adding: content/images/generated_img_27_1.png (stored 0%)
#   adding: content/images/generated_img_33_1.png (stored 0%)
#   adding: content/images/generated_img_31_1.png (stored 0%)
#   adding: content/images/generated_img_20_2.png (stored 0%)
#   adding: content/images/generated_img_28_0.png (stored 0%)
#   adding: content/images/generated_img_31_0.png (stored 0%)
#   adding: content/images/generated_img_31_2.png (stored 0%)
#   adding: content/images/generated_img_17_2.png (stored 0%)
#   adding: content/images/generated_img_23_2.png (stored 0%)
#   adding: content/images/generated_img_5_1.png (stored 0%)
#   adding: content/images/generated_img_8_0.png (stored 0%)
#   adding: content/images/generated_img_40_1.png (stored 0%)
#   adding: content/images/generated_img_44_1.png (stored 0%)
