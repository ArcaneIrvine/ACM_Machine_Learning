# %% [markdown]
# # Lesson 3) Supervised/Unsupervised Learning

# %% [markdown]
# ***
# ## Chapter 1) Introduction to Supervised Learning - Regression and Classification
# ***

# %% [markdown]
# ### 1.1 What is Supervised Learning?

# %% [markdown]
# ### 1.2 Regression

# %% [markdown]
# ### 1.3 Classification

# %% [markdown]
# ### 1.4 Evaluation Metrics

# %% [markdown]
# ***
# ## Chapter 2) Introduction to Unsupervised Learning - Clustering
# ***

# %% [markdown]
# ***
# ## Chapter 3) Preparing Data for Supervised/Unsupervised Learning
# ***
